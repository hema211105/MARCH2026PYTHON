# %%
learning_paths = {
    "Data Science": ["Python", "Pandas", "ML"],
    "Data Engineering": ["ADF", "ADLS", "Databricks"],
}
student_ratings = {"Alice": 4.5, "Bob": 4.8}

# %%
print("learning_paths : {learning_paths}")
# Out:
# learning_paths : {learning_paths}

# %%
learning_paths["Data Science"]
# Out:
# ['Python', 'Pandas', 'ML']

# %%
learning_paths["Cloud Computing"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 learning_paths["Cloud Computing"]
#
# KeyError: 'Cloud Computing'

# %%
learning_paths.get("Cloud Computing")

# %%
learning_paths.get("Cloud Computing","None")
# Out:
# 'None'

# %%
learning_paths["Azure DevOps"] = ["GitHub", "Pipelines", "Terraform"]
learning_paths
# Out:
# {'Data Science': ['Python', 'Pandas', 'ML'],
#  'Data Engineering': ['ADF', 'ADLS', 'Databricks'],
#  'Azure DevOps': ['GitHub', 'Pipelines', 'Terraform']}

# %%
learning_paths["Data Science"] = ["Python", "Pandas", "ML", "Visualization"]
learning_paths
# Out:
# {'Data Science': ['Python', 'Pandas', 'ML', 'Visualization'],
#  'Data Engineering': ['ADF', 'ADLS', 'Databricks'],
#  'Azure DevOps': ['GitHub', 'Pipelines', 'Terraform']}

# %%
student_ratings
# Out:
# {'Alice': 4.5, 'Bob': 4.8}

# %%
student_ratings["Charlie"] = 4.2
student_ratings
# Out:
# {'Alice': 4.5, 'Bob': 4.8, 'Charlie': 4.2}

# %%
student_ratings["Bob"] = 4.9
student_ratings
# Out:
# {'Alice': 4.5, 'Bob': 4.9, 'Charlie': 4.2}

# %%
learning_paths = {
    "Data Science": ["Python", "Pandas", "ML"],
    "Data Engineering": ["ADF", "ADLS", "Databricks"],
    "Azure DevOps": ["GitHub", "Pipelines", "Terraform"]
}

# %%
de_tools = learning_paths.pop("Data Engineering")
print(de_tools)
learning_paths
# Out:
# ['ADF', 'ADLS', 'Databricks']
# {'Data Science': ['Python', 'Pandas', 'ML'],
#  'Azure DevOps': ['GitHub', 'Pipelines', 'Terraform']}

# %%
ds_tools = learning_paths.pop("Data Science")
print(ds_tools)
learning_paths
# Out:
# ['Python', 'Pandas', 'ML']
# {'Azure DevOps': ['GitHub', 'Pipelines', 'Terraform']}

# %%
ds_tools = learning_paths.pop("Data Science")
print(ds_tools)
learning_paths
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 ds_tools = learning_paths.pop("Data Science")
#       2 print(ds_tools)
#       3 learning_paths
#
# KeyError: 'Data Science'

# %%
ds_tools = learning_paths.pop("Data Science","NO VALUE")
print(ds_tools)
learning_paths
# Out:
# NO VALUE
# {'Azure DevOps': ['GitHub', 'Pipelines', 'Terraform']}

# %%
ado_tools = learning_paths.pop("Azure DevOps")
print(ado_tools)
learning_paths
# Out:
# ['GitHub', 'Pipelines', 'Terraform']
# {}

# %%
learning_paths.pop("Anything")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 learning_paths.pop("Anything")
#
# KeyError: 'Anything'

# %%
learning_paths.pop("Anything",None)

# %%
student_ratings = {"Alice": 4.5, "Bob": 4.8}
bob_ratings = student_ratings.pop("Bob")
print(bob_ratings)
student_ratings
# Out:
# 4.8
# {'Alice': 4.5}

# %%
learning_paths = {
    "Data Science": ["Python", "Pandas", "ML"],
    "Data Engineering": ["ADF", "ADLS", "Databricks"],
    "Azure DevOps": ["GitHub", "Pipelines", "Terraform"]
}

# %%
learning_paths.popitem()
# Out:
# ('Azure DevOps', ['GitHub', 'Pipelines', 'Terraform'])

# %%
learning_paths
# Out:
# {'Data Science': ['Python', 'Pandas', 'ML'],
#  'Data Engineering': ['ADF', 'ADLS', 'Databricks']}

# %%
learning_paths.popitem()
# Out:
# ('Data Engineering', ['ADF', 'ADLS', 'Databricks'])

# %%
learning_paths.popitem()
# Out:
# ('Data Science', ['Python', 'Pandas', 'ML'])

# %%
learning_paths.popitem()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 learning_paths.popitem()
#
# KeyError: 'popitem(): dictionary is empty'

# %%
num_dict = {1: 'a', 2: 'b', 3: 'c'}
k, v = num_dict.popitem()
print(f"({k}: {v})")
# Out:
# (3: c)

# %%
tuple_key_dict = {(0,0): "Origin", (1,1): "Point A"}
k, v = tuple_key_dict.popitem()
print(f"({k}: {v})")
# Out:
# ((1, 1): Point A)

# %%
single_item_dict = {"Edukron": "Institute"}
k, v = single_item_dict.popitem()
print(f"({k}:{v})")
# Out:
# (Edukron:Institute)

# %%
paths_alt_order = {}
paths_alt_order["DS"] = []
paths_alt_order["DE"] = []
paths_alt_order["ADO"] = []
k, v = paths_alt_order.popitem()
print(f"({k}:{v})")
# Out:
# (ADO:[])

# %%
d = {'x': 1, 'y': 2}
popped_pair = d.popitem()
popped_key = popped_pair[0]
popped_value = popped_pair[1]
print(popped_key)
print(popped_value)
# Out:
# y
# 2

# %%
learning_paths = {
    "Data Science": ["Python", "Pandas", "ML"],
    "Data Engineering": ["ADF", "ADLS", "Databricks"],
    "Azure DevOps": ["GitHub", "Pipelines", "Terraform"]
}

# %%
learning_paths.keys()
# Out:
# dict_keys(['Data Science', 'Data Engineering', 'Azure DevOps'])

# %%
learning_paths.values()
# Out:
# dict_values([['Python', 'Pandas', 'ML'], ['ADF', 'ADLS', 'Databricks'], ['GitHub', 'Pipelines', 'Terraform']])

# %%
path_items = learning_paths.items()
path_items
# Out:
# dict_items([('Data Science', ['Python', 'Pandas', 'ML']), ('Data Engineering', ['ADF', 'ADLS', 'Databricks']), ('Azure DevOps', ['GitHub', 'Pipelines', 'Terraform'])])

# %%
list(path_items)
# Out:
# [('Data Science', ['Python', 'Pandas', 'ML']),
#  ('Data Engineering', ['ADF', 'ADLS', 'Databricks']),
#  ('Azure DevOps', ['GitHub', 'Pipelines', 'Terraform'])]

# %%
print("\nIterating over keys:")
for path_name in learning_paths.keys():
    print(f"   - Path: {path_name}")
# Out:
# Iterating over keys:
#    - Path: Data Science
#    - Path: Data Engineering
#    - Path: Azure DevOps

# %%
print("\nIterating over values:")
for path_name in learning_paths.values():
    print(f"   - Path: {path_name}")
# Out:
# Iterating over values:
#    - Path: ['Python', 'Pandas', 'ML']
#    - Path: ['ADF', 'ADLS', 'Databricks']
#    - Path: ['GitHub', 'Pipelines', 'Terraform']

# %%
print("\nIterating over items:")
for path_name in learning_paths.items():
    print(f"   - Path: {path_name}")
# Out:
# Iterating over items:
#    - Path: ('Data Science', ['Python', 'Pandas', 'ML'])
#    - Path: ('Data Engineering', ['ADF', 'ADLS', 'Databricks'])
#    - Path: ('Azure DevOps', ['GitHub', 'Pipelines', 'Terraform'])

# %%
print("\nIterating over items:")
for path_name, tool_list in learning_paths.items():
    print(f"   - Path: {path_name}, First tool: {tool_list[0] if tool_list else 'N/A'}")
# Out:
# Iterating over items:
#    - Path: Data Science, First tool: Python
#    - Path: Data Engineering, First tool: ADF
#    - Path: Azure DevOps, First tool: GitHub

# %%
student_ratings = {"Alice": 4.5, "Bob": 4.8}
print(student_ratings.values())
student_ratings["Charlie"] = 4.2
student_ratings
# Out:
# dict_values([4.5, 4.8])
# {'Alice': 4.5, 'Bob': 4.8, 'Charlie': 4.2}

# %%
"Data Science" in learning_paths.keys()
# Out:
# True

# %%
["Python", "Pandas", "ML"] in learning_paths.values()
# Out:
# True
