# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps"]
tech_skills = ("Python", "SQL", "Git", "CI/CD")
words = ['Learn', 'Data', 'Engineering']

# %%
",".join(course_list)
# Out:
# 'Data Science,Data Engineering,Azure DevOps'

# %%
" ".join(course_list)
# Out:
# 'Data Science Data Engineering Azure DevOps'

# %%
"-".join(course_list)
# Out:
# 'Data Science-Data Engineering-Azure DevOps'

# %%
institute = "Edukron"
chars=list(institute)
chars
# Out:
# ['E', 'd', 'u', 'k', 'r', 'o', 'n']

# %%
"".join(chars)
# Out:
# 'Edukron'

# %%
single_item_list = ["Azure DevOps"]
"    ,    ".join(single_item_list)
# Out:
# 'Azure DevOps'

# %%
empty_list = []
",     ".join(empty_list)
# Out:
# ''

# %%
"_".join(tech_skills)
# Out:
# 'Python_SQL_Git_CI/CD'

# %%
report = "\n".join(tech_skills)
print(f"9.Joining with new_line : \n{report}")
# Out:
# 9.Joining with new_line :
# Python
# SQL
# Git
# CI/CD

# %%
mixed_list = ["Data Science", 101]
error_join = ", ".join(mixed_list)
print(f"error:{error_join}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 mixed_list = ["Data Science", 101]
# ----> 2 error_join = ", ".join(mixed_list)
#       3 print(f"error:{error_join}")
#
# TypeError: sequence item 1: expected str instance, int found

# %%
mixed_list = ["Data Science", 101]
try:
    error_join = ", ".join(mixed_list)
except TypeError as e:
    print(f"Error joining list with non-string: {e}")
# Out:
# Error joining list with non-string: sequence item 1: expected str instance, int found

# %%
institute = "Edukron"
course_slogan = "Learn Data Engineering with Real-Time Projects"
filename = "edukron_report.pdf"

# %%
institute.startswith("Edu")
# Out:
# True

# %%
institute.startswith("Data")
# Out:
# False

# %%
filename.endswith("df")
# Out:
# True

# %%
course_slogan.startswith(("Learn", "Hi"))
# Out:
# True

# %%
course_slogan.startswith(("Learn", "Hi", "Java"))
# Out:
# True

# %%
course_slogan.startswith("Engin", 11)
# Out:
# True

# %%
course_slogan.endswith("ime",36)
# Out:
# False

# %%
course_slogan.endswith("ime",0,36)
# Out:
# False

# %%
course_slogan.endswith("Real-Time", 0, 36)
# Out:
# False

# %%
#find,index operations
course_slogan = "Learn Data Engineering with Real-Time Projects"
tech_stack = "Azure DevOps and Python"

# %%
course_slogan.find("Data")
# Out:
# 6

# %%
course_slogan.find("java")
# Out:
# -1

# %%
tech_stack.index("Azure")
# Out:
# 0

# %%
course_slogan.find("Engineering", 10)
# Out:
# 11

# %%
course_slogan.find("Engineering", 12)
# Out:
# -1

# %%
course_slogan.index("Engineering")
# Out:
# 11

# %%
course_slogan.rfind("e")
# Out:
# 42

# %%
course_slogan.find("Eng", 10, 16)
# Out:
# 11

# %%
"".find("h")
# Out:
# -1
