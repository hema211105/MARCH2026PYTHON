# %%
data_sci_skills = {"Python", "Pandas", "ML", "SQL"}
data_eng_skills = {"Python", "SQL", "ADF", "ADLS", "Databricks"}
devops_skills = {"GitHub", "Pipelines", "Terraform", "Python"}

# %%
all_data_skills = data_sci_skills.union(data_eng_skills)
all_data_skills
# Out:
# {'ADF', 'ADLS', 'Databricks', 'ML', 'Pandas', 'Python', 'SQL'}

# %%
all_data_skills1 = data_sci_skills | (data_eng_skills)
all_data_skills1
# Out:
# {'ADF', 'ADLS', 'Databricks', 'ML', 'Pandas', 'Python', 'SQL'}

# %%
common_data_skills = data_sci_skills.intersection(data_eng_skills)
common_data_skills
# Out:
# {'Python', 'SQL'}

# %%
common_data_skills1 = data_sci_skills & (data_eng_skills)
common_data_skills1
# Out:
# {'Python', 'SQL'}

# %%
ds_only_skills = data_sci_skills.difference(data_eng_skills)
ds_only_skills
# Out:
# {'ML', 'Pandas'}

# %%
de_only_skills = data_eng_skills.difference(data_sci_skills)
de_only_skills
# Out:
# {'ADF', 'ADLS', 'Databricks'}

# %%
ds_only_skills1 = data_sci_skills - (data_eng_skills)
ds_only_skills1
# Out:
# {'ML', 'Pandas'}

# %%
non_common_data_skills = data_sci_skills.symmetric_difference(data_eng_skills)
non_common_data_skills
# Out:
# {'ADF', 'ADLS', 'Databricks', 'ML', 'Pandas'}

# %%
non_common_data_skills1 = data_sci_skills ^ (data_eng_skills)
non_common_data_skills1
# Out:
# {'ADF', 'ADLS', 'Databricks', 'ML', 'Pandas'}

# %%
common_all_three = data_sci_skills & data_eng_skills & devops_skills
common_all_three
# Out:
# {'Python'}

# %%
ds_skills_copy = data_sci_skills.copy()
ds_skills_copy.update(data_eng_skills)
ds_skills_copy
# Out:
# {'ADF', 'ADLS', 'Databricks', 'ML', 'Pandas', 'Python', 'SQL'}

# %%
ds_skills_copy1 = data_sci_skills.copy()
ds_skills_copy1 |= data_eng_skills
ds_skills_copy1
# Out:
# {'ADF', 'ADLS', 'Databricks', 'ML', 'Pandas', 'Python', 'SQL'}

# %%
ds_skills_copy = data_sci_skills.copy()
ds_skills_copy.intersection_update(data_eng_skills)
ds_skills_copy
# Out:
# {'Python', 'SQL'}

# %%
ds_skills_copy = data_sci_skills.copy()
ds_skills_copy.difference_update(devops_skills)
ds_skills_copy
# Out:
# {'ML', 'Pandas', 'SQL'}
