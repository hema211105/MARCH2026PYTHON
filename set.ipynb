# %%
data_analytics_topics = {"Visualization", "Power BI", "EDA", "Reporting", "Power BI"}

# %%
data_analytics_topics
# Out:
# {'EDA', 'Power BI', 'Reporting', 'Visualization'}

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps", "Data Science"]
unique_courses = set(course_list)
unique_courses
# Out:
# {'Azure DevOps', 'Data Engineering', 'Data Science'}

# %%
required_skills = set()
required_skills
# Out:
# set()

# %%
required_skills.add("Python")
required_skills
# Out:
# {'Python'}

# %%
required_skills.add("SQL")
required_skills
# Out:
# {'Python', 'SQL'}

# %%
required_skills.add("Python")
required_skills
# Out:
# {'Python', 'SQL'}

# %%
batch_ids = {101, 102}
batch_ids.add(103)
batch_ids
# Out:
# {101, 102, 103}

# %%
config_params = {("host", "localhost")}
config_params.add(("port", 8080))
config_params
# Out:
# {('host', 'localhost'), ('port', 8080)}

# %%
unique_chars = set("Edukron Institute")
unique_chars
# Out:
# {' ', 'E', 'I', 'd', 'e', 'i', 'k', 'n', 'o', 'r', 's', 't', 'u'}

# %%
unique_chars = set(("Edukron Institute"))
unique_chars
# Out:
# {' ', 'E', 'I', 'd', 'e', 'i', 'k', 'n', 'o', 'r', 's', 't', 'u'}

# %%
devops_tools = {"Docker", "Kubernetes"}
data_tools = {"Python", "SQL", "Pandas"}
new_tools_list = ["Terraform", "GitHub Actions", "Docker"] # Note duplicate "Docker"
more_skills = ("Git", "SQL") # Note duplicate "SQL"

# %%
devops_tools.update(new_tools_list)
devops_tools
# Out:
# {'Docker', 'GitHub Actions', 'Kubernetes', 'Terraform'}

# %%
data_tools.update(more_skills)
data_tools
# Out:
# {'Git', 'Pandas', 'Python', 'SQL'}

# %%
all_tools = data_tools.copy()
all_tools.update(devops_tools)
all_tools
# Out:
# {'Docker',
#  'Git',
#  'GitHub Actions',
#  'Kubernetes',
#  'Pandas',
#  'Python',
#  'SQL',
#  'Terraform'}

# %%
chars = {'a', 'b'}
chars.update("ace")
chars
# Out:
# {'a', 'b', 'c', 'e'}

# %%
initial_set = {1,2}
initial_set.update([])
initial_set
# Out:
# {1, 2}

# %%
empty_set = set()
empty_set.update([101, 102, 101])
empty_set
# Out:
# {101, 102}

# %%
numbers = {1, 5}
numbers.update(range(3,6))
numbers
# Out:
# {1, 3, 4, 5}

# %%
features = {"Login"}
features.update(["Profile", "Settings"], ("Logout", "Profile"))
features
# Out:
# {'Login', 'Logout', 'Profile', 'Settings'}

# %%
set_a = {1, 2}
set_b = {2, 3}
set_a |= set_b
set_a
# Out:
# {1, 2, 3}

# %%
devops_tools = {"Docker", "Kubernetes", "Terraform", "GitHub Actions"}
devops_tools.remove("Terraform")
devops_tools
# Out:
# {'Docker', 'GitHub Actions', 'Kubernetes'}

# %%
devops_tools.remove("Terraform")
devops_tools
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 devops_tools.remove("Terraform")
#       2 devops_tools
#
# KeyError: 'Terraform'

# %%
devops_tools.discard("Terraform")
devops_tools
# Out:
# {'Docker', 'GitHub Actions', 'Kubernetes'}

# %%
#discarding using conditions
topics = {"EDA", "Visualization", "Power BI"}
topics_to_remove = "SQL"
topics.discard(topics_to_remove)
topics
# Out:
# {'EDA', 'Power BI', 'Visualization'}

# %%
#pop functions
data_analytics_topics = {"Visualization", "Power BI", "EDA", "Reporting"}
numbers = {101, 102, 103}

# %%
popped_item = data_analytics_topics.pop()
print(popped_item)
data_analytics_topics
# Out:
# Visualization
# {'EDA', 'Power BI', 'Reporting'}

# %%
popped_number = numbers.pop()
print(popped_number)
numbers
# Out:
# 101
# {102, 103}

# %%
popped_number_1 = numbers.pop()
print(popped_number_1)
numbers
# Out:
# 102
# {103}

# %%
popped_number_2 = numbers.pop()
print(popped_number_2)
numbers
# Out:
# 103
# set()

# %%
#Attempt to pop from the now empty set (KeyError)
try:
    numbers.pop()
except KeyError as e:
    print(f"Error popping from empty set: {e}")
# Out:
# Error popping from empty set: 'pop from an empty set'

# %%
single_set = {"Edukron"}
item = single_set.pop()
single_set
# Out:
# set()

# %%
coord_set = {(0,0), (1,1), (2,2)}
coord_set.pop()
coord_set
# Out:
# {(0, 0), (2, 2)}

# %%
mixed_set = {1, "hello", None, True}#True collided with one so true will not be printed
mixed_set.pop()
mixed_set
# Out:
# {1, None}
