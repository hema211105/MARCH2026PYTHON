# %%
num = int(input("Enter a number: "))
result = 10/num
print(result)
print("Calculation is done")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 num = int(input("Enter a number: "))
#       2 result = 10/num
#       3 print(result)
#       4 print("Calculation is done")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
try:
    num = int(input("Enter a number: "))
    result =10/num
    print("Result:", result)
except ValueError:
    print("Invalid input! Please enter a number.")
except ZeroDivisionError:
    print("Division by Zero is not allowed.")

print("Completed")
# Out:
# Result: 0.05
# Completed

# %%
#file reading without exception handling
file = open("data.txt", "r")
content = file.read()
print(content)
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 #file reading without exception handling
# ----> 2 file = open("data.txt", "r")
#       3 content = file.read()
#       4 print(content)
#       5 file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.txt'

# %%
#file reading with exception handlings
try:
    file = open("data.txt", "r")
    content = file.read()
    print(content)
except FileNotFoundError:
    print("File not found! Please Check filename.")
finally:
    print("Operation Finished")
# Out:
# File not found! Please Check filename.
# Operation Finished

# %%
# Converting Input Without Exception Handling
age = int(input("Enter your age: "))
print("Your age is:", age)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Converting Input Without Exception Handling
# ----> 2 age = int(input("Enter your age: "))
#       3 print("Your age is:", age)
#
# ValueError: invalid literal for int() with base 10: 'twenty'

# %%
# Converting Input With Exception Handling
try:
    age = int(input("Enter your age: "))
    print("Your age is:", age)
except ValueError:
    print("Invalid age! Enter numeric value only.")
# Out:
# Your age is: 20

# %%
try:
    num = int(input("Enter a number: "))
    result =10/num
    print("Result:", result)
except ValueError:
    print("Invalid input! Please enter a number.")
except ZeroDivisionError:
    print("Division by Zero is not allowed.")
# Out:
# Division by Zero is not allowed.

# %%
try:
    num = int(input("Enter a number: "))
    x = 10/num
except Exception as e:
    print(f"An error occured: {e}")
# Out:
# An error occured: division by zero

# %%
#handling multiple exception handlings
try:
    data =[1,2,3]
    index = int(input("Enter index:"))
    print(data[index])
except IndexError:
    print("error:Index out of range!")
except ValueError:
    print("Error: Invalid input!Enter an integer.")
except Exception as e:
    print(f"Unexpected error:{e}")
# Out:
# 1

# %%
try:
    value = int(input("Enter a number"))
    result = 100/value
    print(f"Result:{result}")
except (ValueError, ZeroDivisionError) as e:
    print("your custom message")
    print(f"Debug info: {e}")
# Out:
# your custom message
# Debug info: division by zero

# %%
try: 
    file = open("none.txt", "r")
except FileNotFoundError as e:
    print(f"File error: {e}")
    print(f"Error type: {type(e).__name__}")
# Out:
# File error: [Errno 2] No such file or directory: 'none.txt'
# Error type: FileNotFoundError

# %%
file = None
try: 
    file = open("data.txt", "r")
    content = file.read()
    print(content)
except FileNotFoundError:
    print("File not found!")
finally:
    if file:
        file.close()
        print("File Closed successfully")
# Out:
# File not found!

# %%
import sqlite3
connection = None
try:
    connection = sqlite3.connect("database.db")
    cursor = connection.cursor()
    cursor.execute("SELECT * FROM users")
    results = cursor.fetchall()
    print(results)
except sqlite3.Error as e:
    print(f"Database error: {e}")
finally:
    if connection:
        connection.close()
        print("Database connection closed")
# Out:
# Database error: no such table: users
# Database connection closed

# %%
try:
    num1 = float(input("Enter first number:"))
    num2 = float(input("Enter Second number"))
    result = num1 / num2
except ValueError:
    print("Invalid input! Please enter numbers.")
except ZeroDivisionError:
    print("Cannot divide by zero!")
else:
    print(f"Result: {result}")
    print("Calculation successful!")
finally:
    print("Calculator Shut down.")
# Out:
# Result: 0.0
# Calculation successful!
# Calculator Shut down.

# %%
try:
    with open("data.csv", "r") as file:
        data = file.read()
except FileNotFoundError:
    print("File not found!")
else:
    print("File read successfully")
    print(f"Data length: {len(data)} characters")
finally:
    print("File operation completed")
# Out:
# File not found!
# File operation completed

# %%
def set_age(age):
    if age < 0:
        raise ValueError("Age can't be -ve!")
    if age > 150:
        raise ValueError("Age seems unrealistic!")
    return age
try:
    user_age = set_age(-5)
except ValueError as e:
    print(f"Error: {e}")
# Out:
# Error: Age can't be -ve!

# %%
def divide(a,b):
    try:
        return a / b
    except ZeroDivisionError:
        print("Logging: Division by zero attempted")
        raise
try:
    result = divide(10,0)
except ZeroDivisionError:
    print("Handled in outer scope")
# Out:
# Logging: Division by zero attempted
# Handled in outer scope

# %%
def process_data(data):
    try:
        return int(data)
    except ValueError:
        raise TypeError(f"Cannot convert '{data}' to integer")
try:
    process_data("abc")
except TypeError as e:
    print(e)
# Out:
# Cannot convert 'abc' to integer
