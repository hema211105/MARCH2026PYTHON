# %%
def deposit(amount):
    global balance
    balance += amount
    print(f"Deposited {amount}. New balance {balance}")

# %%
def withdraw(amount):
    global balance
    if balance>=amount:
        balance-=amount
        print(f"Withdrawn: {amount}. New balance {balance}")
    else:
        print("Insufficient balance")

# %%
def check_balance():
    global balance
    print(f"Current balance: {balance}")

# %%
account_number = "ACC001"
account_holder = "Hema"
balance = 5000

# %%
deposit(10000)
# Out:
# Deposited 10000. New balance 15000

# %%
withdraw(5000)
# Out:
# Withdrawn: 5000. New balance 10000

# %%
withdraw(12000)
# Out:
# Insufficient balance

# %%
balance
# Out:
# 10000

# %%
class BankAccount:
    def __init__(self,account_number,account_holder,balance):
        self.account_number = account_number
        self.account_holder = account_holder
        self.balance = balance
    def deposit(self,amount):
        self.balance += amount
        print(f"Deposited: ${amount}. New balance: ${balance}")
    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
            print(f"Withdrawn: ${amount}. New balance: ${self.balance}")
        else:
            print("Insufficient funds!")
    def check_balance(self):
        print(f"Current balance: ${self.balance}")

# %%
def dog():
    print("Dog is barking")

# %%
dog()
# Out:
# Dog is barking

# %%
account1 = BankAccount("ACC001", "Anil", 5000)
account2 = BankAccount("ACC002", "Sunil", 4000)

# %%
account1.deposit(1000)
# Out:
# Deposited: $1000. New balance: $10000

# %%
account1.withdraw(5000)
# Out:
# Insufficient funds!

# %%
account1.check_balance()
# Out:
# Current balance: $2000
