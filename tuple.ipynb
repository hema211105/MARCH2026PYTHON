# %%
tech_skills = ("Python", "SQL", "Git", "CI/CD", "Python")
course_info = ("DS101", "Data Science", 15, 4.8) # ID, Name, Weeks, Rating

# %%
{tech_skills}
# Out:
# {('Python', 'SQL', 'Git', 'CI/CD', 'Python')}

# %%
tech_skills[1]
# Out:
# 'SQL'

# %%
tech_skills[-1]
# Out:
# 'Python'

# %%
tech_skills[:2]
# Out:
# ('Python', 'SQL')

# %%
tech_skills[-2:]
# Out:
# ('CI/CD', 'Python')

# %%
course_info[1], course_info[3]
# Out:
# ('Data Science', 4.8)

# %%
empty_tuple = ()
{empty_tuple}
# Out:
# {()}

# %%
single_tool = ("Azure",)
print(f"6. Single element tuple: {single_tool}, Type: {type(single_tool)}")
# Out:
# 6. Single element tuple: ('Azure',), Type: <class 'tuple'>

# %%
student_record = "Alice", 101, "DS"
{student_record}
# Out:
# {('Alice', 101, 'DS')}

# %%
course_id, course_name, duration, rating = course_info
{course_name},{duration}
# Out:
# ({'Data Science'}, {15})

# %%
nested_tuple = (1, 2, ("a", "b"), 3)
nested_tuple[2][1]
# Out:
# 'b'

# %%
tech_skills = ("Python", "SQL", "Git", "CI/CD", "Python", "SQL", "Python")
ratings = (5, 4, 5, 5, 3, 4, 5)

# %%
tech_skills.count("Python")
# Out:
# 3

# %%
mixed_tuple = (1, "Python", True, 1, "Python", 1, False)
mixed_tuple.count(1)
# Out:
# 4

# %%
mixed_tuple.count(True)
# Out:
# 4

# %%
mixed_tuple.count(False)
# Out:
# 1

# %%
mixed_tuple.count(0)
# Out:
# 1

# %%
nested = (1, (2, 3), 4, (2, 3))
nested.count((2,3))
# Out:
# 2

# %%
empty_count = ().count("anything")
empty_count
# Out:
# 0

# %%
tech_skills = ("Python", "SQL", "Git", "CI/CD", "Python", "SQL")
ratings = (5, 4, 5, 5, 3, 4, 5)

# %%
tech_skills.index("SQL")
# Out:
# 1

# %%
tech_skills.index("Java")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 tech_skills.index("Java")
#
# ValueError: tuple.index(x): x not in tuple

# %%
ratings.index(5)
# Out:
# 0

# %%
tech_skills.index("Python",1,2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 tech_skills.index("Python",1,2)
#
# ValueError: tuple.index(x): x not in tuple

# %%
tech_skills.index("Python",1)
# Out:
# 4

# %%
tech_skills.index("SQL",2)
# Out:
# 5

# %%
ratings.index(4,2,6)
# Out:
# 5

# %%
nested = (1, (2, 3), 4, (2, 3))
nested.index((2,3))
# Out:
# 1
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
